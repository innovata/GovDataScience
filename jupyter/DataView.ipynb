# %%
from _jupyterEnv import *
# Out:
# 2023-06-13 08:24:19,231 | INFO | [69764/MainProcess][73604/MainThread] | idebug.set_viewEnvType[159] | <ipylib.idebug.Debugger object at 0x00000228AF1A2400> | 1 (1: print | 2: logger | 3: jupyter)
# C:\Python39
# C:\Python39\DLLs
# C:\Python39\lib
# C:\Python39\python39.zip
# C:\pypjts\GovDataScience\src
# c:\pypjts\GovDataScience\govDataScienceEnv_py39_64bit
# c:\pypjts\GovDataScience\govDataScienceEnv_py39_64bit\lib\site-packages
# c:\pypjts\GovDataScience\govDataScienceEnv_py39_64bit\lib\site-packages\Pythonwin
# c:\pypjts\GovDataScience\govDataScienceEnv_py39_64bit\lib\site-packages\win32
# c:\pypjts\GovDataScience\govDataScienceEnv_py39_64bit\lib\site-packages\win32\lib
# c:\pypjts\GovDataScience\jupyter
# LogLevel: 10 (DEBUG) c:\pypjts\GovDataScience\govDataScienceEnv_py39_64bit\lib\site-packages\ipylib\idebug.py

# %%
reload_all()
datamodels.LocationCode().view()
# Out:
# {'CodesLen': 277}
# {'DataLen': 25}
# {'FrameLen': 25}
#          법정동코드        법정동명 폐지여부   지역코드
# 0   1168000000   서울특별시 강남구   존재  11680
# 1   1174000000   서울특별시 강동구   존재  11740
# 2   1130500000   서울특별시 강북구   존재  11305
# 3   1150000000   서울특별시 강서구   존재  11500
# 4   1162000000   서울특별시 관악구   존재  11620
# 5   1121500000   서울특별시 광진구   존재  11215
# 6   1153000000   서울특별시 구로구   존재  11530
# 7   1154500000   서울특별시 금천구   존재  11545
# 8   1135000000   서울특별시 노원구   존재  11350
# 9   1132000000   서울특별시 도봉구   존재  11320
# 10  1123000000  서울특별시 동대문구   존재  11230
# 11  1159000000   서울특별시 동작구   존재  11590
# 12  1144000000   서울특별시 마포구   존재  11440
# 13  1141000000  서울특별시 서대문구   존재  11410
# 14  1165000000   서울특별시 서초구   존재  11650
# 15  1120000000   서울특별시 성동구   존재  11200
# 16  1129000000   서울특별시 성북구   존재  11290
# 17  1171000000   서울특별시 송파구   존재  11710
# 18  1147000000   서울특별시 양천구   존재  11470
# 19  1156000000  서울특별시 영등포구   존재  11560
# 20  1117000000   서울특별시 용산구   존재  11170
# 21  1138000000   서울특별시 은평구   존재  11380
# ...

# %%
reload_all()
datamodels.CHECKLIST_RealEstate().inspect()
# Out:
# 법정동명 0 []
# 지역코드 5 ['11350', '11440', '11650', '11680', '11710']
# dataName 4 ['getRTMSDataSvcAptRent', 'getRTMSDataSvcAptTradeDev', 'getRTMSDataSvcRHRent', 'getRTMSDataSvcRHTrade']
# totalCount 1179 [0, 3, 4, 6, 7, 9, 11, 13, 15, 16]
# 계약연월 402 ['199001', '199002', '199003', '199004', '199005', '199006', '199007', '199008', '199009', '199010']
# numOfRows 2 [10, 1000]
# pageNo 1 [1]
# resultCode 1 ['00']
# resultMsg 1 ['NORMAL SERVICE.']

# %%
reload_all()
datamodels.CHECKLIST_RealEstate().view().tail(10)
# Out:
# {'필터': {'totalCount': {'$gt': 0}}}
# {'DataLen': 2938}
# {'FrameLen': 2938}
#                        dataName    계약연월   지역코드  numOfRows  pageNo resultCode
# 2928      getRTMSDataSvcRHTrade  200602  11350         10       1         00  \
# 2929      getRTMSDataSvcRHTrade  200602  11440         10       1         00
# 2930  getRTMSDataSvcAptTradeDev  200601  11680       1000       1         00
# 2931  getRTMSDataSvcAptTradeDev  200601  11710       1000       1         00
# 2932  getRTMSDataSvcAptTradeDev  200601  11350       1000       1         00
# 2933  getRTMSDataSvcAptTradeDev  200601  11440       1000       1         00
# 2934      getRTMSDataSvcRHTrade  200601  11680         10       1         00
# 2935      getRTMSDataSvcRHTrade  200601  11710         10       1         00
# 2936      getRTMSDataSvcRHTrade  200601  11350         10       1         00
# 2937      getRTMSDataSvcRHTrade  200601  11440         10       1         00
#
#             resultMsg  totalCount
# ...

# %%
reload_all()
datamodels.CHECKLIST_RealEstate().target_ReqPool('getRTMSDataSvcAptTradeDev')
# Out:
# {'DataLen': 24}
# {'PoolLen': 4361}
# [('11740', '202306'),
#  ('11740', '202305'),
#  ('11740', '202304'),
#  ('11740', '202303'),
#  ('11740', '202302'),
#  ('11740', '202301'),
#  ('11740', '202212'),
#  ('11740', '202211'),
#  ('11740', '202210'),
#  ('11740', '202209'),
#  ('11740', '202208'),
#  ('11740', '202207'),
#  ('11740', '202206'),
#  ('11740', '202205'),
#  ('11740', '202204'),
#  ('11740', '202203'),
#  ('11740', '202202'),
#  ('11740', '202201'),
#  ('11740', '202112'),
#  ('11740', '202111'),
#  ('11740', '202110'),
#  ('11740', '202109'),
#  ('11740', '202108'),
#  ('11740', '202107'),
#  ('11740', '202106'),
#  ('11740', '202105'),
#  ('11740', '202104'),
#  ('11740', '202103'),
#  ('11740', '202102'),
#  ('11740', '202101'),
#  ('11740', '202012'),
#  ('11740', '202011'),
#  ('11740', '202010'),
#  ('11740', '202009'),
#  ('11740', '202008'),
#  ('11740', '202007'),
#  ('11740', '202006'),
#  ('11740', '202005'),
#  ('11740', '202004'),
#  ('11740', '202003'),
# ...

# %%
reload_all()
# schmodels.RealState().__create__()
schmodels.RealState().view()
# Out:
#    seq      column dtype role           desc     unit
# 0    _     해제사유발생일  date    _              _        _
# 1    _        거래금액   int    _         단위: 만원  10000.0
# 2    _        건축년도   int    _              _        _
# 3    _           년   int    _              _        _
# 4    _           월   int    _              _        _
# 5    _           일   int    _              _        _
# 6    _           층   int    _              _        _
# 7    _        거래유형   str    _              _        _
# 8    _        검색연월   str    _  OpenAPI함수 입력값        _
# 9    _         도로명   str    _              _        _
# 10   _  도로명건물본번호코드   str    _              _        _
# 11   _  도로명건물부번호코드   str    _              _        _
# 12   _    도로명시군구코드   str    _              _        _
# 13   _   도로명일련번호코드   str    _              _        _
# 14   _   도로명지상지하코드   str    _              _        _
# 15   _       도로명코드   str    _              _        _
# ...

# %%
reload_all()
datamodels.AptTradeRealContract().inspect()
# Out:
# 거래금액 3237 [650, 750, 900, 950, 1000, 1050, 1100, 1120, 1200, 1250]
# 거래유형 2 ['중개거래', '직거래']
# 건축년도 60 [None, 1962, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973]
# 검색연월 0 []
# 년 2 [2022, 2023]
# 도로명 7575 [None, '10용사로', '1공단로9길', '63로', '가곡13길', '가곡15길', '가곡4길', '가곡5길', '가곡7길', '가곡8길']
# 도로명건물본번호코드 1240 [None, 7, 12, 14, 16, 29, 38, 60, 76, 86]
# 도로명건물부번호코드 116 [None, 0, 1, '0', '0.0', '1', '1.0', '10', '10.0', '102']
# 도로명시군구코드 118 [None, 11620, '11110', '11140', '11170', '11230', '11260', '11290', '11320', '11350']
# 도로명일련번호코드 24 [0, 1, '0', '1', '10', '11', '12', '13', '14', '15']
# 도로명지상지하코드 5 [None, nan, 0.0, '0', '0.0']
# 도로명코드 8088 [None, 2000003, 2005010, 3005083, 3120002, 3120008, 3120009, 4160018, 4160021, 4160023]
# 법정동 1582 ['가곡동', '가남읍 신해리', '가남읍 심석리', '가남읍 태평리', '가능동', '가락동', '가리봉동', '가사동', '가수동', '가야동']
# 법정동본번코드 2407 [None, 10, 15, 602, 863, 893, 1000, 1135, 1522, 1574]
# 법정동부번코드 275 [None, 0, 1, 5, 9, 12, 17, 31, 40, 51]
# ...

# %%
# reload_all()
# dup, net = datamodels.AptTradeRealContract().dedup_data()
# net

# %%
df.loc[: , ['년','월','일','일련번호','지역코드']]
# Out:
#            년  월  일       일련번호   지역코드
# 2       2023  6  3  11680-218  11680
# 3       2023  6  3  11680-301  11680
# 4       2023  6  3  11680-218  11680
# 5       2023  6  3  11680-301  11680
# 7       2023  6  2  11680-382  11680
# ...      ... .. ..        ...    ...
# 290963  2006  1  2  11680-214  11680
# 290964  2006  1  2  11680-214  11680
# 290965  2006  1  2  11680-109  11680
# 290966  2006  1  2  11680-306  11680
# 290967  2006  1  2  11680-319  11680
#
# [260685 rows x 5 columns]

# %%
reload_all()
datamodels.AptTradeRealContract().view()
# Out:
#                           _id       법정동코드        법정동명 폐지여부   지역코드
# 0    64702c703e7146d1ad149ea8  1111000000   서울특별시 종로구   존재  11110
# 1    64702c703e7146d1ad149f05  1114000000    서울특별시 중구   존재  11140
# 2    64702c703e7146d1ad149f5a  1117000000   서울특별시 용산구   존재  11170
# 3    64702c703e7146d1ad149ffd  1123000000  서울특별시 동대문구   존재  11230
# 4    64702c703e7146d1ad14a036  1126000000   서울특별시 중랑구   존재  11260
# ..                        ...         ...         ...  ...    ...
# 189  64702c703e7146d1ad154e7b  4885000000    경상남도 하동군   존재  48850
# 190  64702c703e7146d1ad154f00  4886000000    경상남도 산청군   존재  48860
# 191  64702c703e7146d1ad154f9b  4887000000    경상남도 함양군   존재  48870
# 192  64702c703e7146d1ad155013  4888000000    경상남도 거창군   존재  48880
# 193  64702c703e7146d1ad155085  4889000000    경상남도 합천군   존재  48890
#
# [194 rows x 5 columns]
# 업데이트중... ['11110', '서울특별시', '종로구']
# 업데이트중... ['11140', '서울특별시', '중구']
# 업데이트중... ['11170', '서울특별시', '용산구']
# 업데이트중... ['11230', '서울특별시', '동대문구']
# ...

# %%
reload_all()
datamodels.AptRent().view()
# Out:
# 2023-06-08 00:01:16,824 | INFO | [38892/MainProcess][37356/MainThread] | govdatascience.dataengine.datamodels._manipulate01
# {'필터': {'지역1': {'$regex': '서울'}}}
# {'DataLen': 135439}
# {'DataLen': 135439}
# {'FrameLen': 135439}
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135439 entries, 0 to 135438
# Data columns (total 33 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   거래금액        135439 non-null  int64
#  1   거래유형        135439 non-null  object
#  2   건축년도        135439 non-null  int64
#  3   년           135439 non-null  int64
#  4   도로명         135439 non-null  object
#  5   도로명건물본번호코드  135439 non-null  object
#  6   도로명건물부번호코드  135439 non-null  object
#  7   도로명시군구코드    135439 non-null  object
#  8   도로명일련번호코드   135439 non-null  object
#  9   도로명지상지하코드   127466 non-null  object
#  10  도로명코드       135439 non-null  object
#  11  법정동         135439 non-null  object
#  12  법정동본번코드     135439 non-null  object
# ...

# %%
reload_all()
# ecos.build_StatisticTableList()
datamodels.BOKStatisticTableList().view()
