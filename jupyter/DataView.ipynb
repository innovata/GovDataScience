# %%
from _jupyterEnv import *

# %%
reload_all()

# %%
reload_all()
datamodels.ApartmentRealTrade().view()
# Out:
# {'DataLen': 102}
# {'FrameLen': 102}
#                           _id     거래금액  거래유형  건축년도     년        도로명
# 0    647022db3e7146d1ad149e98  180,000  중개거래  2004  2023     새문안로3길  \
# 1    647022db3e7146d1ad149e99   38,000  중개거래  2003  2023   돈화문로11가길
# 2    647022db3e7146d1ad149e9a   17,000  중개거래  2017  2023        대학로
# 3    647022db3e7146d1ad149e9b   39,800  중개거래  2002  2023        창신길
# 4    647022db3e7146d1ad149e9c   13,400  중개거래  2013  2023      종로66길
# ..                        ...      ...   ...   ...   ...        ...
# 97   647051d7c16133fb431a1acf   29,000  중개거래  2017  2023   상모로273번길
# 98   647051d7c16133fb431a1ad0   11,500  중개거래  2000  2023   비행장로55번길
# 99   647051d7c16133fb431a1ad1   19,500  중개거래  2019  2023        신영로
# 100  647051d7c16133fb431a1ad2    9,000   직거래  2001  2023       서성일로
# 101  647051d7c16133fb431a1ad3   28,300  중개거래  2017  2023  화순중앙로12번길
#
#      도로명건물본번호코드  도로명건물부번호코드  도로명시군구코드  도로명일련번호코드  ...  월   일        일련번호
# ...

# %%
df = pd.DataFrame(data)
df

# %%
reload_all()
# datamodels.LocationCode().__create__()
df = datamodels.LocationCode().view()
df
# Out:
# {'CodesLen': 277}
# {'DataLen': 142}
# {'FrameLen': 1}
#                         _id       법정동코드     법정동명 폐지여부   지역코드
# 0  64702c703e7146d1ad14b769  4148000000  경기도 파주시   존재  41480

# %%
df[-60:]

# %%
reload_all()
datamodels.AptRealTradesCollectChecklist().view()
# Out:
# {'DataLen': 34282}
# {'FrameLen': 34282}
#                             _id        법정동명   지역코드   개수    검색연월
# 0      6471949c3e7146d1ad1553fe   서울특별시 종로구  11110   16  202305
# 1      6471949c3e7146d1ad1553ff    서울특별시 중구  11140   17  202305
# 2      6471949c3e7146d1ad155400   서울특별시 용산구  11170   12  202305
# 3      6471949c3e7146d1ad155401  서울특별시 동대문구  11230   75  202305
# 4      6471949c3e7146d1ad155402   서울특별시 중랑구  11260   30  202305
# ...                         ...         ...    ...  ...     ...
# 34277  6471949d3e7146d1ad15d9e3    경상남도 사천시  48240  NaN  200001
# 34278  6471949d3e7146d1ad15d9e4    경상남도 김해시  48250  NaN  200001
# 34279  6471949d3e7146d1ad15d9e5    경상남도 밀양시  48270  NaN  200001
# 34280  6471949d3e7146d1ad15d9e6    경상남도 거제시  48310  NaN  200001
# 34281  6471949d3e7146d1ad15d9e7    경상남도 양산시  48330  NaN  200001
#
# [34282 rows x 5 columns]

# %%
reload_all()
datamodels.AptRentsChecklist().view()
# Out:
# {'DataLen': 34282}
# {'FrameLen': 34282}
#                             _id        법정동명   지역코드    검색연월
# 0      6471cd3c165e3f26dec74684   서울특별시 종로구  11110  202305  \
# 1      6471cd3c165e3f26dec74685    서울특별시 중구  11140  202305
# 2      6471cd3c165e3f26dec74686   서울특별시 용산구  11170  202305
# 3      6471cd3c165e3f26dec74687  서울특별시 동대문구  11230  202305
# 4      6471cd3c165e3f26dec74688   서울특별시 중랑구  11260  202305
# ...                         ...         ...    ...     ...
# 34277  6471cd3d165e3f26dec7cc69    경상남도 사천시  48240  200001
# 34278  6471cd3d165e3f26dec7cc6a    경상남도 김해시  48250  200001
# 34279  6471cd3d165e3f26dec7cc6b    경상남도 밀양시  48270  200001
# 34280  6471cd3d165e3f26dec7cc6c    경상남도 거제시  48310  200001
# 34281  6471cd3d165e3f26dec7cc6d    경상남도 양산시  48330  200001
#
#                     dataName numOfRows pageNo resultCode        resultMsg
# 0      getRTMSDataSvcAptRent        10      1         00  NORMAL SERVICE.  \
# ...

# %%
reload_all()
datamodels.ApartmentRent().view()
# Out:
# {'DataLen': 34}
# {'FrameLen': 34}
#                          _id     거래금액  거래유형  건축년도     년      도로명  도로명건물본번호코드
# 0   6471cda87d6887e9934d11c3  270,000  중개거래  2010  2023      퇴계로          72  \
# 1   6471cda87d6887e9934d11c4  260,000  중개거래  2000  2023  동호로20가길          38
# 2   6471cda87d6887e9934d11c5  200,000  중개거래  2000  2023  동호로20가길          38
# 3   6471cda87d6887e9934d11c6   43,000   직거래  2018  2023     마른내로         126
# 4   6471cda87d6887e9934d11c7   84,000  중개거래  1999  2023    청구로1길          23
# 5   6471cda87d6887e9934d11c8  116,000   직거래  2002  2023      다산로          32
# 6   6471cda87d6887e9934d11c9   95,000  중개거래  2002  2023      다산로          32
# 7   6471cda87d6887e9934d11ca  139,500  중개거래  2011  2023      청구로          64
# 8   6471cda87d6887e9934d11cb   15,500  중개거래  2014  2023      난계로         151
# 9   6471cda87d6887e9934d11cc   92,000  중개거래  2008  2023     청계천로         400
# 10  6471cda87d6887e9934d11cd   79,700  중개거래  2008  2023     청계천로         400
# ...
